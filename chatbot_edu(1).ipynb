# %%
# !pip install "pymongo[srv]"
# !pip install pymongo google-generativeai
import numpy as np
# Out:
# ...
# WARNING: pymongo 4.16.0 does not provide the extra 'srv'
# ...

# %%
from google import genai
API_KEY= "AIzaSyCD__NA0E5F-Hyd_pj2OIwKqv6PG75vJ8E"
client=genai.Client(api_key=API_KEY)
while True:
    question=input("You: ")
    if question.lower() =="exit":
      print("Edulearn AI Chatbot:Goodbye")
      break
    response=client.models.generate_content( model="gemini-2.5-flash",contents=question)
    print(f"\nEdulearn AI Chatbot:{response.text}")
# Out:
# You:  what is a cell
# Edulearn AI Chatbot:A **cell** is the fundamental, structural, and functional unit of all known living organisms. It's often called the "building block of life."
#
# Here's a breakdown of what that means:
#
# 1.  **Smallest Unit of Life:** For something to be considered "alive," it must be composed of at least one cell. Viruses, for example, are not considered true living organisms because they lack the cellular machinery to reproduce on their own.
#
# 2.  **Self-Contained:** Each cell is enclosed by a membrane (the **cell membrane** or plasma membrane) that separates its internal contents from the external environment. This membrane controls what enters and leaves the cell.
#
# 3.  **Contains Genetic Material:** All cells contain genetic material, typically **DNA**, which holds the instructions for the cell's structure, function, and reproduction.
#
# 4.  **Performs Life Functions:** Cells are capable of carrying out all the essential processes of life:
# ...

# %%
from pymongo import MongoClient

CONNECTION_STRING = "mongodb+srv://winniemutitu_db_user:3YjLUw0l5ekVlUDq@edulearn.4mcdat3.mongodb.net/?appName=Edulearn"

# 2. Initialize the client
client = MongoClient(CONNECTION_STRING)

# 3. Access your specific database and collection
db = client['chatbot_db']
chat_history = db['messages']

# %%
def hybrid_chat(user_question):
    context = get_context(user_question)
    try:
        if context:
            prompt = f"""
Answer ONLY using this lesson content:

    {context}

    Question:
    {user_question}
"""
        else:
            prompt = "This topic is not in the curriculum."

        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt
        )

        return "ONLINE MODE:\n" + response.text

    except:
        if context:
            return "OFFLINE MODE:\n" + context
        else:
            return "OFFLINE MODE:\nTopic not available."
